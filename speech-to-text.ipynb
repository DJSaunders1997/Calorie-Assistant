# %% [markdown]
# # Speech to text test
#
# Using this article as a reference

# %%
#import libraries

import speech_recognition as sr
import re # Regular Expressions
from win32com.client import Dispatch

# %%
# Seeing what microphones we have avaliable

for index, name in enumerate(sr.Microphone.list_microphone_names()):
    print(f"Microphone with name \"{name}\" found for `Microphone(device_index={index})`".format(index, name))
# Out:
# Microphone with name "Microsoft Sound Mapper - Input" found for `Microphone(device_index=0)`
# Microphone with name "Microphone (Plantronics C320)" found for `Microphone(device_index=1)`
# Microphone with name "Microphone (Realtek Audio)" found for `Microphone(device_index=2)`
# Microphone with name "Microsoft Sound Mapper - Output" found for `Microphone(device_index=3)`
# Microphone with name "Speakers / Headphones (Realtek " found for `Microphone(device_index=4)`
# Microphone with name "Speakers (Plantronics C320)" found for `Microphone(device_index=5)`
# Microphone with name "Primary Sound Capture Driver" found for `Microphone(device_index=6)`
# Microphone with name "Microphone (Plantronics C320)" found for `Microphone(device_index=7)`
# Microphone with name "Microphone (Realtek Audio)" found for `Microphone(device_index=8)`
# Microphone with name "Primary Sound Driver" found for `Microphone(device_index=9)`
# Microphone with name "Speakers / Headphones (Realtek Audio)" found for `Microphone(device_index=10)`
# Microphone with name "Speakers (Plantronics C320)" found for `Microphone(device_index=11)`
# Microphone with name "Realtek ASIO" found for `Microphone(device_index=12)`
# Microphone with name "Speakers (Plantronics C320)" found for `Microphone(device_index=13)`
# Microphone with name "Speakers / Headphones (Realtek Audio)" found for `Microphone(device_index=14)`
# Microphone with name "Microphone (Plantronics C320)" found for `Microphone(device_index=15)`
# Microphone with name "Microphone (Realtek Audio)" found for `Microphone(device_index=16)`
# Microphone with name "Speakers (Realtek HD Audio output)" found for `Microphone(device_index=17)`
# Microphone with name "Microphone (Realtek HD Audio Mic input)" found for `Microphone(device_index=18)`
# Microphone with name "Stereo Mix (Realtek HD Audio Stereo input)" found for `Microphone(device_index=19)`
# Microphone with name "Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free AG Audio%0
# ;(Mpow H7))" found for `Microphone(device_index=20)`
# Microphone with name "Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free AG Audio%0
# ;(Mpow H7))" found for `Microphone(device_index=21)`
# Microphone with name "Output (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(Pixel 3a XL))" found for `Microphone(device_index=22)`
# Microphone with name "Input (@System32\drivers\bthhfenum.sys,#4;%1 Hands-Free HF Audio%0
# ;(Pixel 3a XL))" found for `Microphone(device_index=23)`
# Microphone with name "Headphones ()" found for `Microphone(device_index=24)`
# Microphone with name "Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free AG Audio%0
# ;(BT-FAAH))" found for `Microphone(device_index=25)`
# Microphone with name "Headset (@System32\drivers\bthhfenum.sys,#2;%1 Hands-Free AG Audio%0
# ;(BT-FAAH))" found for `Microphone(device_index=26)`
# Microphone with name "Microphone (Plantronics C320)" found for `Microphone(device_index=27)`
# Microphone with name "Speakers (Plantronics C320)" found for `Microphone(device_index=28)`
# Microphone with name "Headphones ()" found for `Microphone(device_index=29)`

# %%
# Above didnt seem to do anything!!!

# Try this instead
# https://www.techwithtim.net/tutorials/voice-assistant/wake-keyword/

# %%
# Create Speaking function

# This is windows only at the moment, will have to change if I deploy on pi
def speak(text):
    print(f'Speaking:: {text}')
    Dispatch("SAPI.SpVoice").Speak(text)

speak("Boo lets go for a walk") # test
# Out:
# Speaking:: Boo lets go for a walk

# %%
def get_audio():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        audio = r.listen(source)
        said = ""

        try:
            said = r.recognize_google(audio)
            print(said)
        except Exception as e:
            print(f"Exception {str(e)}: All I heard was {said}" )

    return said.lower()

# %%
get_audio()
# Out:
# Exception : All I heard was
# ''

# %%
# Adding calories logic

def calorie_events(text, total_calories):

    if 'add' in text:
        print('Adding calories')

        reg_ex = re.search(r'\d+', text) # search for any digits

        # If digits were found
        if reg_ex:
            calorie_amount = reg_ex.group(0) # If there are multiple numbers then add the first one
            
            speak(f'Adding {calorie_amount} to your daily total')
            total_calories = total_calories + int(calorie_amount)
            speak(f'Total calorie consumed is now {total_calories}')

        # If no digits were found
        else:
            speak('No numbers were said, so I cant add anything sorry!')
    
    # Reducing calories function
    elif ('minus' in text) or ('take away' in text) or ('reduce' in text):
        print('Reducing calories')

        reg_ex = re.search(r'\d+', text) # search for any digits

        # If digits were found
        if reg_ex:
            calorie_amount = reg_ex.group(0) # If there are multiple numbers then add the first one
            
            speak(f'Taking away {calorie_amount} from your daily total')
            total_calories = total_calories - int(calorie_amount)
            speak(f'Total calorie consumed is now {total_calories}')

        # If no digits were found
        else:
            speak('No numbers were said, so I cant add anything sorry!')    
    
    
    else:
        speak('Please specify what calorie action you would like to perform')

    return total_calories   # Need to return so next runthough will be able to know calories

# %%
wake_word = 'barry' # name needs to lowercase!!

# %%
# initilise calories outside of loop so it should increase
total_calories = 0

# %%
while True:
    print("Listening")
    background_speech = get_audio()

    #print(f'I just heard {text}') # for debugging only

    # Wake word detection
    # TODO: See if I can bypass the 'Yo watup' and add calores straight away if calories keyword is detected
    if wake_word in background_speech:
        print("Wakeword heard")
        speak("Yo watup")
        text = get_audio()

        if 'calories' in text:
            total_calories = calorie_events(text, total_calories)
            
        else:
            speak('You didnt say any phrases I can respond to yet. Sorry!')
# Out:
# Listening
# Exception : All I heard was
# Listening
# yeah Barry
# Wakeword heard
# Speaking:: Yo watup
# add 300 calories
# Adding calories
# Speaking:: Adding 300 to your daily total
# Speaking:: Total calorie consumed is now 300
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# little Kelly defence
# Listening
# Exception : All I heard was
# Listening
# yeah I did call you last night because
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Barry
# Wakeword heard
# Speaking:: Yo watup
# 400 calories
# Speaking:: Please specify what calorie action you would like to perform
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# Exception : All I heard was
# Listening
# call Barry
# Wakeword heard
# Speaking:: Yo watup
# Exception : All I heard was
# Speaking:: You didnt say any phrases I can respond to yet. Sorry!
# Listening
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-b42a26f7b7e2> in <module>
#       1 while True:
#       2     print("Listening")
# ----> 3     background_speech = get_audio()
#       4
#       5     #print(f'I just heard {text}') # for debugging only
#
# <ipython-input-5-7b1da3b18688> in get_audio()
#       2     r = sr.Recognizer()
#       3     with sr.Microphone() as source:
# ----> 4         audio = r.listen(source)
#       5         said = ""
#       6
#
# C:\Python39\lib\site-packages\speech_recognition\__init__.py in listen(self, source, timeout, phrase_time_limit, snowboy_configuration)
#     618                         raise WaitTimeoutError("listening timed out while waiting for phrase to start")
#     619
# --> 620                     buffer = source.stream.read(source.CHUNK)
#     621                     if len(buffer) == 0: break  # reached end of the stream
#     622                     frames.append(buffer)
#
# C:\Python39\lib\site-packages\speech_recognition\__init__.py in read(self, size)
#     159
#     160         def read(self, size):
# --> 161             return self.pyaudio_stream.read(size, exception_on_overflow=False)
#     162
#     163         def close(self):
#
# C:\Python39\lib\site-packages\pyaudio.py in read(self, num_frames, exception_on_overflow)
#     606                           paCanNotReadFromAnOutputOnlyStream)
#     607
# --> 608         return pa.read_stream(self._stream, num_frames, exception_on_overflow)
#     609
#     610     def get_read_available(self):
#
# KeyboardInterrupt:
